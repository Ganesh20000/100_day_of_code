# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r'./datasets/coffee.csv')

# %%
bios = pd.read_csv(r'./datasets/athlete_events.csv')

# %%
df['new_price'] = 55

# %%
df.tail()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 9     Friday       Latte          35         55
# 10  Saturday    Espresso          45         55
# 11  Saturday       Latte          35         55
# 12    Sunday    Espresso          45         55
# 13    Sunday       Latte          35         55

# %%
df['new_price'] = np.where(df['Coffee Type']=='Espresso', 2.88 , 6.99)

# %%
np.where(df['Day']=='Monday','Wednesday','Tuesday')
# Out:
# array(['Wednesday', 'Wednesday', 'Tuesday', 'Tuesday', 'Tuesday',
#        'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday', 'Tuesday',
#        'Tuesday', 'Tuesday', 'Tuesday'], dtype='<U9')

# %%
df.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       2.88
# 1     Monday       Latte          15       6.99
# 2    Tuesday    Espresso          30       2.88
# 3    Tuesday       Latte          20       6.99
# 4  Wednesday    Espresso          35       2.88

# %%
df_n = df
df_n.rename(columns={'new_price':'NEW_PRICE'})
# Out:
#           Day Coffee Type  Units Sold  NEW_PRICE
# 0      Monday    Espresso          25       2.88
# 1      Monday       Latte          15       6.99
# 2     Tuesday    Espresso          30       2.88
# 3     Tuesday       Latte          20       6.99
# 4   Wednesday    Espresso          35       2.88
# 5   Wednesday       Latte          25       6.99
# 6    Thursday    Espresso          40       2.88
# 7    Thursday       Latte          30       6.99
# 8      Friday    Espresso          45       2.88
# 9      Friday       Latte          35       6.99
# 10   Saturday    Espresso          45       2.88
# 11   Saturday       Latte          35       6.99
# 12     Sunday    Espresso          45       2.88
# 13     Sunday       Latte          35       6.99

# %%
df.head()
# Out:
#          Day Coffee Type  Units Sold  new_price
# 0     Monday    Espresso          25       2.88
# 1     Monday       Latte          15       6.99
# 2    Tuesday    Espresso          30       2.88
# 3    Tuesday       Latte          20       6.99
# 4  Wednesday    Espresso          35       2.88

# %%
bios.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
bios_n = bios.copy()

# %%
bios_n['NAME'] = bios['Name'].str.split(' ').str[0]

# %%
bios_n
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
def h(x):
    if x<=165:
        print("short")
    elif 165 < x<=190:
        print("avg")
    elif x>190:
        print("high")

# %%
df['Coffee Type'].value_counts(ascending=False)
# Out:
# Coffee Type
# Espresso    7
# Latte       7
# Name: count, dtype: int64
