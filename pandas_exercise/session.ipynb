# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv(r'./datasets/movies.csv')

# %%
df.head(2)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
# 1             Battalion 609  tt9472208
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 1             Battalion 609             Battalion 609         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
# 1             2019     131               War          4.1          73
#
#                                                story  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
df.shape
# Out:
# (1629, 18)

# %%
df.isna()
# Out:
#       title_x  imdb_id  poster_path  wiki_link  title_y  original_title  \
# 0       False    False        False      False    False           False
# 1       False    False         True      False    False           False
# 2       False    False        False      False    False           False
# 3       False    False        False      False    False           False
# 4       False    False         True      False    False           False
# ...       ...      ...          ...        ...      ...             ...
# 1624    False    False        False      False    False           False
# 1625    False    False        False      False    False           False
# 1626    False    False         True      False    False           False
# 1627    False    False        False      False    False           False
# 1628    False    False        False      False    False           False
#
#       is_adult  year_of_release  runtime  genres  imdb_rating  imdb_votes  \
# ...

# %%
df.isna().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
df.isna().any()
# Out:
# title_x             False
# imdb_id             False
# poster_path          True
# wiki_link           False
# title_y             False
# original_title      False
# is_adult            False
# year_of_release     False
# runtime             False
# genres              False
# imdb_rating         False
# imdb_votes          False
# story                True
# summary             False
# tagline              True
# actors               True
# wins_nominations     True
# release_date         True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
df[['actors','title_y','release_date']].head()
# Out:
#                                               actors  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1  Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2  Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3  Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4  Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#
#                          title_y             release_date
# 0       Uri: The Surgical Strike    11 January 2019 (USA)
# 1                  Battalion 609  11 January 2019 (India)
# 2  The Accidental Prime Minister    11 January 2019 (USA)
# 3                Why Cheat India    18 January 2019 (USA)
# 4                Evening Shadows  11 January 2019 (India)

# %%
type(df['actors'])
# Out:
# pandas.core.series.Series

# %%
df =df.fillna(method='ffill')
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_19756\3187907699.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df =df.fillna(method='ffill')

# %%
df.dropna(inplace=True)

# %%
df.isna().any()
# Out:
# title_x             False
# imdb_id             False
# poster_path         False
# wiki_link           False
# title_y             False
# original_title      False
# is_adult            False
# year_of_release     False
# runtime             False
# genres              False
# imdb_rating         False
# imdb_votes          False
# story               False
# summary             False
# tagline             False
# actors              False
# wins_nominations    False
# release_date        False
# dtype: bool

# %%
df.isna().sum()
# Out:
# title_x             0
# imdb_id             0
# poster_path         0
# wiki_link           0
# title_y             0
# original_title      0
# is_adult            0
# year_of_release     0
# runtime             0
# genres              0
# imdb_rating         0
# imdb_votes          0
# story               0
# summary             0
# tagline             0
# actors              0
# wins_nominations    0
# release_date        0
# dtype: int64

# %% [markdown]
# movies with higher rating than 8 and vote 10000

# %%
df.head()
# Out:
#                              title_x    imdb_id  \
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# 10                            Amavas  tt8396186
# 11                         Gully Boy  tt2395469
#
#                                           poster_path  \
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 7            https://en.wikipedia.org/wiki/Bombairiya
# 8   https://en.wikipedia.org/wiki/Manikarnika:_The...
# 9      https://en.wikipedia.org/wiki/Thackeray_(film)
# 10               https://en.wikipedia.org/wiki/Amavas
# 11            https://en.wikipedia.org/wiki/Gully_Boy
#
# ...

# %%
r8_v_10k =df[(df['imdb_rating']>8) & (df['imdb_votes']>100000)]

# %%
r8_v_10k.shape
# Out:
# (5, 18)

# %%
#action movies with higher rating than 7.5

# %%
df.head()
# Out:
#                              title_x    imdb_id  \
# 7                         Bombairiya  tt4971258
# 8   Manikarnika: The Queen of Jhansi  tt6903440
# 9                   Thackeray (film)  tt7777196
# 10                            Amavas  tt8396186
# 11                         Gully Boy  tt2395469
#
#                                           poster_path  \
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 8   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 10  https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 7            https://en.wikipedia.org/wiki/Bombairiya
# 8   https://en.wikipedia.org/wiki/Manikarnika:_The...
# 9      https://en.wikipedia.org/wiki/Thackeray_(film)
# 10               https://en.wikipedia.org/wiki/Amavas
# 11            https://en.wikipedia.org/wiki/Gully_Boy
#
# ...

# %%
def s(a):
    genes= a.split('|')
    return 'Action' in genes

# %%
act =df['genres'].str.split('|').apply(lambda x:'Action' in x)

# %%
act2 = df['genres'].apply(s)

# %%
rate_75 =df['imdb_rating']>7.5

# %%
rate_75.head(1)
# Out:
# 7    False
# Name: imdb_rating, dtype: bool

# %%
df[act & rate_75].shape
# Out:
# (32, 18)

# %%
df[act2& rate_75].shape
# Out:
# (32, 18)

# %%
df[act2& rate_75].head(1)
# Out:
#                  title_x    imdb_id  \
# 41  Family of Thakurganj  tt8897986
#
#                                           poster_path  \
# 41  https://upload.wikimedia.org/wikipedia/en/9/99...
#
#                                             wiki_link               title_y  \
# 41  https://en.wikipedia.org/wiki/Family_of_Thakur...  Family of Thakurganj
#
#           original_title  is_adult  year_of_release runtime        genres  \
# 41  Family of Thakurganj         0             2019     127  Action|Drama
#
#     imdb_rating  imdb_votes  \
# 41          9.4         895
#
#                                                 story  \
# 41  The film is based on small town of North India...
#
#                                               summary  \
# 41  The film is based on small town of North India...
#
#                                               tagline  \
# 41  Inspired by the Life of Anand Kumar & His Stud...
#
# ...

# %% [markdown]
# adding new column

# %%
df['Country'] = 'India'

# %%
df['Country']
# Out:
# 7       India
# 8       India
# 9       India
# 10      India
# 11      India
#         ...
# 1624    India
# 1625    India
# 1626    India
# 1627    India
# 1628    India
# Name: Country, Length: 1622, dtype: object

# %%
def ac(x):
    ac = x.split('wins')
    return ac[0]

# %%
win =df['wins_nominations'].apply(ac)

# %%
def act(x):
    acc = x.split('|')
    return acc[0]

# %%
df['actors'].str.split('|').apply(lambda x : x[0]).head()
# Out:
# 7            Radhika Apte
# 8          Kangana Ranaut
# 9     Nawazuddin Siddiqui
# 10              Ali Asgar
# 11          Ranveer Singh
# Name: actors, dtype: object

# %%
df['actors'].apply(act).tail()
# Out:
# 1624       Ajay Devgn
# 1625    Ameesha Patel
# 1626      Vijay Arora
# 1627     Gippy Grewal
# 1628       Fawad Khan
# Name: actors, dtype: object

# %%
def d(s):
    ss = s.split("& ")
    return ss

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1622 entries, 7 to 1628
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1622 non-null   object
#  1   imdb_id           1622 non-null   object
#  2   poster_path       1622 non-null   object
#  3   wiki_link         1622 non-null   object
#  4   title_y           1622 non-null   object
#  5   original_title    1622 non-null   object
#  6   is_adult          1622 non-null   int64
#  7   year_of_release   1622 non-null   int64
#  8   runtime           1622 non-null   object
#  9   genres            1622 non-null   object
#  10  imdb_rating       1622 non-null   float64
#  11  imdb_votes        1622 non-null   int64
#  12  story             1622 non-null   object
#  13  summary           1622 non-null   object
#  14  tagline           1622 non-null   object
#  15  actors            1622 non-null   object
# ...

# %%
df['actors'].astype('str')
# Out:
# 7       Radhika Apte|Akshay Oberoi|Siddhanth Kapoor|Ra...
# 8       Kangana Ranaut|Rimi Sen|Atul Kulkarni|Nalneesh...
# 9       Nawazuddin Siddiqui|Amrita Rao|Abdul Quadir Am...
# 10      Ali Asgar|Vivan Bhatena|Nargis Fakhri|Sachiin ...
# 11      Ranveer Singh|Alia Bhatt|Siddhant Chaturvedi|V...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1622, dtype: object
