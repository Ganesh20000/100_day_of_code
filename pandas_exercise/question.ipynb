# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Beginner Level Questions
#
# Display the first 10 rows of the dataset.
#
# Show the number of rows and columns (shape).
#
# List all unique continents in the dataset.
#
# Find the capital city of India.
#
# Show the top 5 countries with the highest population.
#
# Select only the columns: country, continent, population.
#
# Which country has the minimum population?
#
# Find all countries in Asia.

# %%
df = pd.read_csv(r'Countries.csv')

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
#Display the first 10 rows of the dataset.
df.iloc[:10]
# Out:
#                country                             country_long  \
# 0          Afghanistan             Islamic State of Afghanistan
# 1              Albania                      Republic of Albania
# 2              Algeria  People's Democratic Republic of Algeria
# 3              Andorra                  Principality of Andorra
# 4               Angola              People's Republic of Angola
# 5  Antigua and Barbuda                      Antigua and Barbuda
# 6            Argentina                       Argentine Republic
# 7              Armenia                      Republic of Armenia
# 8            Australia                Commonwealth of Australia
# 9              Austria                      Republic of Austria
#
#                 currency      capital_city                     region  \
# 0         Afghan afghani             Kabul              Southern Asia
# 1           Albanian lek            Tirana            Southern Europe
# ...

# %%
df.shape
# Out:
# (194, 64)

# %%
df.nunique()
# Out:
# country             194
# country_long        194
# currency            142
# capital_city        194
# region               22
#                    ...
# democracy_score     146
# democracy_type        5
# median_age          143
# political_leader    187
# title                17
# Length: 64, dtype: int64

# %%
df[df['country']=='India']['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df.sort_values(by='population',ascending=False).head()
# Out:
#            country                  country_long           currency  \
# 75           India             Republic of India       Indian rupee
# 34           China    People's Republic of China       Chinese yuan
# 184  United States      United States of America        U.S. dollar
# 76       Indonesia         Republic of Indonesia  Indonesian rupiah
# 129       Pakistan  Islamic Republic of Pakistan    Pakistani rupee
#
#          capital_city              region continent     demonym  latitude  \
# 75          New Delhi       Southern Asia      Asia      Indian      20.0
# 34            Beijing        Eastern Asia      Asia     Chinese      35.0
# 184  Washington, D.C.    Northern America  Americas    American      38.0
# 76            Jakarta  South-Eastern Asia      Asia  Indonesian      -5.0
# 129         Islamabad       Southern Asia      Asia   Pakistani      30.0
#
#      longitude  agricultural_land  ...  population  \
# 75        77.0          1790450.0  ...  1417173173
# ...

# %%
df[['country','continent','population']]
# Out:
#                 country continent  population
# 0           Afghanistan      Asia    41128771
# 1               Albania    Europe     2775634
# 2               Algeria    Africa    44903225
# 3               Andorra    Europe       79824
# 4                Angola    Africa    35588987
# ..                  ...       ...         ...
# 189             Vietnam      Asia    98186856
# 190  West Bank and Gaza      Asia     5043612
# 191               Yemen      Asia    33696614
# 192              Zambia    Africa    20017675
# 193            Zimbabwe    Africa    16320537
#
# [194 rows x 3 columns]

# %% [markdown]
# Intermediate Level Questions
#
# Calculate the mean population of all countries.
#
# Find the country with the highest GDP.
#
# Sort countries by life_expectancy in descending order.
#
# Group by continent and find the average population.
#
# Find all countries with urban_population > rural_population.
#
# Which continent has the maximum total forest_area?
#
# Count how many countries are classified as "Full democracy".
#
# For each continent, find the median democracy_score.
#
# Which country has the highest electricity_access_pct?
#
# List all countries where internet_pct > 90.

# %%
df['population'].mean()
# Out:
# np.float64(40788877.788659796)

# %%
df[df['gdp']==df['gdp'].max()]
# Out:
#            country              country_long     currency      capital_city  \
# 184  United States  United States of America  U.S. dollar  Washington, D.C.
#
#                region continent   demonym  latitude  longitude  \
# 184  Northern America  Americas  American      38.0      -97.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# 184          4058100.0  ...   333287557                     28.7037
#
#      rural_population  urban_population  press  democracy_score  \
# 184          56378923         276908634   3.04             7.96
#
#        democracy_type  median_age  political_leader      title
# 184  Flawed democracy        33.9         Joe Biden  President
#
# [1 rows x 64 columns]

# %%
df.sort_values(by='life_expectancy',ascending=False).head()
# Out:
#            country                   country_long           currency  \
# 97   Liechtenstein  Principality of Liechtenstein        Swiss franc
# 83           Japan                          Japan       Japanese yen
# 88           Korea              Republic of Korea         Korean won
# 165    Switzerland                    Switzerland        Swiss franc
# 8        Australia      Commonwealth of Australia  Australian dollar
#
#     capital_city                     region continent          demonym  \
# 97         Vaduz             Western Europe    Europe  Liechtensteiner
# 83         Tokyo               Eastern Asia      Asia         Japanese
# 88         Seoul               Eastern Asia      Asia     South Korean
# 165         Bern             Western Europe    Europe            Swiss
# 8       Canberra  Australia and New Zealand   Oceania       Australian
#
#       latitude   longitude  agricultural_land  ...  population  \
# ...

# %%
df.groupby('continent')['population'].mean()
# Out:
# continent
# Africa      2.638538e+07
# Americas    2.936354e+07
# Asia        9.953398e+07
# Europe      1.678467e+07
# Oceania     3.134620e+06
# Name: population, dtype: float64

# %%
df[df['urban_population'] >df['rural_population']]['country']
# Out:
# 1                 Albania
# 2                 Algeria
# 3                 Andorra
# 4                  Angola
# 6               Argentina
#               ...
# 184         United States
# 185               Uruguay
# 186            Uzbekistan
# 188             Venezuela
# 190    West Bank and Gaza
# Name: country, Length: 129, dtype: object

# %%
df[df['forest_area'] ==df['forest_area'].max()]
# Out:
#     country        country_long       currency capital_city          region  \
# 140  Russia  Russian Federation  Russian ruble       Moscow  Eastern Europe
#
#     continent  demonym  latitude  longitude  agricultural_land  ...  \
# 140    Europe  Russian      60.0      100.0          2154940.0  ...
#
#      population  women_parliament_seats_pct  rural_population  \
# 140   143555736                     16.2222          35708054
#
#      urban_population  press  democracy_score  democracy_type  median_age  \
# 140         107847682   1.55             2.94   Authoritarian        35.0
#
#      political_leader      title
# 140    Vladimir Putin  President
#
# [1 rows x 64 columns]

# %%
df.groupby('continent')['forest_area'].sum().idxmax()
# Out:
# 'Americas'

# %%
df[df['democracy_type']=='Full democracy']['country'].count()
# Out:
# np.int64(20)

# %%
df.groupby('continent',as_index=False)['democracy_score'].median()
# Out:
#   continent  democracy_score
# 0    Africa            3.735
# 1  Americas            6.190
# 2      Asia            3.930
# 3    Europe            7.500
# 4   Oceania            0.000

# %%
df[df['electricity_access_pct'] ==df['electricity_access_pct'].max()].head()
# Out:
#                country             country_long               currency  \
# 1              Albania      Republic of Albania           Albanian lek
# 3              Andorra  Principality of Andorra                   Euro
# 5  Antigua and Barbuda      Antigua and Barbuda  East Caribbean dollar
# 6            Argentina       Argentine Republic         Argentine peso
# 7              Armenia      Republic of Armenia          Armenian dram
#
#        capital_city           region continent    demonym  latitude  \
# 1            Tirana  Southern Europe    Europe   Albanian     41.00
# 3  Andorra la Vella  Southern Europe    Europe   Andorran     42.50
# 5      Saint John's        Caribbean  Americas   Antiguan     17.05
# 6      Buenos Aires    South America  Americas  Argentine    -34.00
# 7           Yerevan     Western Asia      Asia   Armenian     40.00
#
#    longitude  agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df.loc[df['internet_pct'] >90,['country','internet_pct']].head()
# Out:
#                 country  internet_pct
# 3               Andorra       93.8975
# 5   Antigua and Barbuda       95.6634
# 8             Australia       96.2400
# 9               Austria       92.5292
# 11              Bahrain      100.0000

# %% [markdown]
# Advanced Level Questions
#
# Create a new column GDP_per_capita = gdp / population.
#
# Find the top 10 countries with highest GDP_per_capita.
#
# For each continent, find the country with the highest GDP.
#
# Compare average life_expectancy of democracies vs authoritarian regimes.
#
# Find the correlation between health_expenditure_pct_gdp and life_expectancy.
#
# Create a new column population_density = population / land_area. Show the top 5 densest countries.
#
# Group by democracy_type and find the average press freedom score.
#
# Find the top 5 countries with the largest difference between rural_population and urban_population.
#
# For each continent, find the total CO2 emissions.
#
# Plot a bar chart of GDP by continent (use Matplotlib).

# %%
df['GDP_per_capita'] = df['gdp'] / df['population']
df['GDP_per_capita'].tail()
# Out:
# 189    4163.510440
# 190    3789.327966
# 191     641.197955
# 192    1487.910059
# 193    1266.998751
# Name: GDP_per_capita, dtype: float64

# %%
df.sort_values(by='GDP_per_capita',ascending=False)
# Out:
#                       country                           country_long  \
# 112                    Monaco                 Principality of Monaco
# 97              Liechtenstein          Principality of Liechtenstein
# 99                 Luxembourg              Grand Duchy of Luxembourg
# 127                    Norway                      Kingdom of Norway
# 79                    Ireland                                Ireland
# ..                        ...                                    ...
# 149              Sierra Leone               Republic of Sierra Leone
# 31   Central African Republic               Central African Republic
# 0                 Afghanistan           Islamic State of Afghanistan
# 26                    Burundi                    Republic of Burundi
# 44   Dem. People's Rep. Korea  Democratic People's Republic of Korea
#
#                                        currency capital_city           region  \
# ...
