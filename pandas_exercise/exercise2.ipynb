# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df =pd.read_csv(r'./datasets/Countries.csv')

# %%
df.tail()
# Out:
#                 country                   country_long            currency  \
# 189             Vietnam  Socialist Republic of Vietnam     Vietnamese dong
# 190  West Bank and Gaza             West Bank and Gaza  Israeli new shekel
# 191               Yemen              Republic of Yemen         Yemeni rial
# 192              Zambia             Republic of Zambia  New Zambian kwacha
# 193            Zimbabwe           Republic of Zimbabwe         U.S. dollar
#
#     capital_city              region continent      demonym   latitude  \
# 189        Hanoi  South-Eastern Asia      Asia   Vietnamese  16.166667
# 190     Ramallah        Western Asia      Asia  Palestinian  31.900000
# 191       Sana'a        Western Asia      Asia       Yemeni  15.000000
# 192       Lusaka      Eastern Africa    Africa      Zambian -15.000000
# 193       Harare      Eastern Africa    Africa   Zimbabwean -20.000000
#
#       longitude  agricultural_land  ...  population  \
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
df.isna().any()
# Out:
# country             False
# country_long        False
# currency            False
# capital_city        False
# region              False
#                     ...
# democracy_score     False
# democracy_type      False
# median_age          False
# political_leader     True
# title                True
# Length: 64, dtype: bool

# %%
df.isna().sum()
# Out:
# country             0
# country_long        0
# currency            0
# capital_city        0
# region              0
#                    ..
# democracy_score     0
# democracy_type      0
# median_age          0
# political_leader    7
# title               7
# Length: 64, dtype: int64

# %%
df[df['population']==df['population'].max()]
# Out:
#    country       country_long      currency capital_city         region  \
# 75   India  Republic of India  Indian rupee    New Delhi  Southern Asia
#
#    continent demonym  latitude  longitude  agricultural_land  ...  population  \
# 75      Asia  Indian      20.0       77.0          1790450.0  ...  1417173173
#
#     women_parliament_seats_pct  rural_population  urban_population  press  \
# 75                     14.9446         908804812         508368361   1.71
#
#     democracy_score    democracy_type  median_age  political_leader  \
# 75             7.23  Flawed democracy        23.9     Narendra Modi
#
#              title
# 75  Prime Minister
#
# [1 rows x 64 columns]

# %%
# df.loc[75].capital_city
df[df['population']==df['population'].max()]['capital_city']
# Out:
# 75    New Delhi
# Name: capital_city, dtype: object

# %%
df[df['population']==df['population'].min()]
# Out:
#     country country_long           currency capital_city     region continent  \
# 179  Tuvalu       Tuvalu  Australian dollar     Funafuti  Polynesia   Oceania
#
#       demonym  latitude  longitude  agricultural_land  ...  population  \
# 179  Tuvaluan      -8.0      178.0               18.0  ...       11312
#
#      women_parliament_seats_pct  rural_population  urban_population  press  \
# 179                        6.25              3900              7412    0.0
#
#      democracy_score  democracy_type  median_age  political_leader  \
# 179              0.0         Unknown        21.0     Kausea Natano
#
#               title
# 179  Prime Minister
#
# [1 rows x 64 columns]

# %%
df[df['population']==df['population'].min()]['capital_city']
# Out:
# 179    Funafuti
# Name: capital_city, dtype: object

# %%
df.nlargest(5,'democracy_score')
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df.sort_values(by='democracy_score',ascending=False).head()
# Out:
#          country         country_long            currency capital_city  \
# 127       Norway    Kingdom of Norway     Norwegian krone         Oslo
# 74       Iceland  Republic of Iceland       Iceland krona    Reykjavík
# 164       Sweden    Kingdom of Sweden       Swedish krona    Stockholm
# 122  New Zealand          New Zealand  New Zealand dollar   Wellington
# 46       Denmark   Kingdom of Denmark        Danish krone   Copenhagen
#
#                         region continent        demonym  latitude  longitude  \
# 127            Northern Europe    Europe      Norwegian      62.0       10.0
# 74             Northern Europe    Europe      Icelander      65.0      -18.0
# 164            Northern Europe    Europe        Swedish      62.0       15.0
# 122  Australia and New Zealand   Oceania  New Zealander     -41.0      174.0
# 46             Northern Europe    Europe         Danish      56.0       10.0
#
#      agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
df['region'].value_counts().count()
# Out:
# np.int64(22)

# %%
df['region'].value_counts()['Eastern Europe']
# Out:
# np.int64(10)

# %%
df[df['region'] =='Eastern Europe']['country']
# Out:
# 14             Belarus
# 24            Bulgaria
# 43      Czech Republic
# 73             Hungary
# 111            Moldova
# 136             Poland
# 139            Romania
# 140             Russia
# 151    Slovak Republic
# 181            Ukraine
# Name: country, dtype: object

# %%
df[df['population'] ==df['population'].nlargest(2).iloc[1]]['political_leader']
# Out:
# 34    Xi Jinping
# Name: political_leader, dtype: object

# %% [markdown]
# how many country are there political leader are missing

# %%
df[df['political_leader'].isna()]['country']
# Out:
# 27                         Cabo Verde
# 151                   Slovak Republic
# 159               St. Kitts and Nevis
# 160                         St. Lucia
# 161    St. Vincent and the Grenadines
# 172                       Timor-Leste
# 190                West Bank and Gaza
# Name: country, dtype: object

# %%
df[df['political_leader'].isna()]['country'].count()
# Out:
# np.int64(7)

# %% [markdown]
# how many country have republic in name

# %%
count=0;
def repu(t):
    global count
    if 'republic' in t.lower():
            count+=1
            
    return count

# %%
def re(t):
    count =0;
    for republic in t:
        if republic in t.lower():
            count+=1;
            
    return count

# %%
print(re(df['country_long']))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11004\2003051848.py in ?()
# ----> 1 print(re(df['country_long']))
#
# ~\AppData\Local\Temp\ipykernel_11004\2075250057.py in ?(t)
#       1 def re(t):
#       2     count =0;
#       3     for republic in t:
# ----> 4         if republic in t.lower():
#       5             count+=1;
#       6
#       7     return count
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# ...

# %% [markdown]
# africa continet which has largest population

# %%
af = df[df['continent']=='Africa']

# %%
af[af['population']==af['population'].max()]['country']
# Out:
# 125    Nigeria
# Name: country, dtype: object

# %%
df[df['country']=='New Zealand']['political_leader']
# Out:
# 122    Jacinda Ardern
# Name: political_leader, dtype: object

# %%
df[df['country']=='China'][['population','rural_population']]
# Out:
#     population  rural_population
# 34  1412175000         514596570

# %% [markdown]
# find all countries with population greather than 50

# %%
df[df['population']>50000000].head()
# Out:
#             country                      country_long          currency  \
# 12       Bangladesh   People's Republic of Bangladesh  Bangladeshi taka
# 22           Brazil     Federative Republic of Brazil    Brazilian real
# 34            China        People's Republic of China      Chinese yuan
# 35         Colombia              Republic of Colombia    Colombian peso
# 45  Dem. Rep. Congo  Democratic Republic of the Congo   Congolese franc
#
#    capital_city         region continent      demonym  latitude  longitude  \
# 12        Dhaka  Southern Asia      Asia  Bangladeshi      24.0       90.0
# 22     Brasília  South America  Americas    Brazilian     -10.0      -55.0
# 34      Beijing   Eastern Asia      Asia      Chinese      35.0      105.0
# 35       Bogotá  South America  Americas    Colombian       4.0      -72.0
# 45     Kinshasa  Middle Africa    Africa    Congolese       0.0       25.0
#
#     agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %% [markdown]
# Get all countries in a specific continent (like Asia).

# %%
asia = df[df['continent']=='Asia']

# %%
asia.head()
# Out:
#         country                     country_long          currency  \
# 0   Afghanistan     Islamic State of Afghanistan    Afghan afghani
# 7       Armenia              Republic of Armenia     Armenian dram
# 10   Azerbaijan           Republic of Azerbaijan   New Azeri manat
# 11      Bahrain               Kingdom of Bahrain    Bahraini dinar
# 12   Bangladesh  People's Republic of Bangladesh  Bangladeshi taka
#
#    capital_city         region continent      demonym  latitude  longitude  \
# 0         Kabul  Southern Asia      Asia       Afghan      33.0      65.00
# 7       Yerevan   Western Asia      Asia     Armenian      40.0      45.00
# 10         Baku   Western Asia      Asia  Azerbaijani      40.5      47.50
# 11       Manama   Western Asia      Asia     Bahraini      26.0      50.55
# 12        Dhaka  Southern Asia      Asia  Bangladeshi      24.0      90.00
#
#     agricultural_land  ...  population  women_parliament_seats_pct  \
# ...

# %%
# If the column name is exactly "GDP per capita"
df.sort_values(by="population", ascending=True).head()
# Out:
#         country            country_long           currency  \
# 179      Tuvalu                  Tuvalu  Australian dollar
# 119       Nauru       Republic of Nauru  Australian dollar
# 130       Palau       Republic of Palau        U.S. dollar
# 143  San Marino  Republic of San Marino               Euro
# 112      Monaco  Principality of Monaco               Euro
#
#            capital_city           region continent      demonym   latitude  \
# 179            Funafuti        Polynesia   Oceania     Tuvaluan  -8.000000
# 119               Yaren       Micronesia   Oceania      Nauruan  -0.533333
# 130           Ngerulmud       Micronesia   Oceania      Palauan   7.500000
# 143  City of San Marino  Southern Europe    Europe  Sammarinese  43.766667
# 112              Monaco   Western Europe    Europe   Monegasque  43.733333
#
#       longitude  agricultural_land  ...  population  \
# 179  178.000000               18.0  ...       11312
# ...

# %%
df.groupby('continent')[['rural_population','urban_population']].median()
# Out:
#            rural_population  urban_population
# continent
# Africa            9043081.0         4824056.5
# Americas          1813679.0         4259528.0
# Asia              7393781.0         8859423.0
# Europe            1500691.0         4663420.5
# Oceania            135433.0           57026.5
