# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('Countries.csv')

# %%
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        3.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.loc[:,['country','region']].head()
# Out:
#        country           region
# 0  Afghanistan    Southern Asia
# 1      Albania  Southern Europe
# 2      Algeria  Northern Africa
# 3      Andorra  Southern Europe
# 4       Angola    Middle Africa

# %%
df.iloc[:,[1,5,6]].head()
# Out:
#                               country_long continent   demonym
# 0             Islamic State of Afghanistan      Asia    Afghan
# 1                      Republic of Albania    Europe  Albanian
# 2  People's Democratic Republic of Algeria    Africa  Algerian
# 3                  Principality of Andorra    Europe  Andorran
# 4              People's Republic of Angola    Africa   Angolan

# %%
df.loc[:,['title','population','rural_population']].head()
# Out:
#                 title  population  rural_population
# 0           President    41128771          30181937
# 1      Prime Minister     2775634           1004807
# 2           President    44903225          11328186
# 3  Head of Government       79824              9730
# 4           President    35588987          11359649

# %%
df.iloc[:,[2,4,6,8,10]].head()
# Out:
#          currency           region   demonym  longitude  forest_area
# 0  Afghan afghani    Southern Asia    Afghan       65.0      12084.4
# 1    Albanian lek  Southern Europe  Albanian       20.0       7889.0
# 2  Algerian dinar  Northern Africa  Algerian        3.0      19490.0
# 3            Euro  Southern Europe  Andorran        1.5        160.0
# 4  Angolan kwanza    Middle Africa   Angolan       18.5     666074.0

# %% [markdown]
# manipulate on value

# %%
df.loc[2,'longitude'] =0000 
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0        0.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.iloc[2,8]=600
df.head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0      600.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %% [markdown]
# sord by values

# %%
df.sort_values('country',ascending=True).head()
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
# 3      Andorra                  Principality of Andorra            Euro
# 4       Angola              People's Republic of Angola  Angolan kwanza
#
#        capital_city           region continent   demonym  latitude  longitude  \
# 0             Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1            Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2           Algiers  Northern Africa    Africa  Algerian      28.0      600.0
# 3  Andorra la Vella  Southern Europe    Europe  Andorran      42.5        1.5
# 4            Luanda    Middle Africa    Africa   Angolan     -12.5       18.5
#
# ...

# %%
df.sort_values(['country','capital_city'],ascending=[1,0])
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %% [markdown]
# filtering data

# %%
df= pd.read_csv(r'athlete_events.csv')
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df[df['Height']>220][['Name','Height','Age','Weight']].head()
# Out:
#                           Name  Height   Age  Weight
# 17669           Gunther Behnke   221.0  29.0   114.0
# 32376     Tommy Loren Burleson   223.0  20.0   102.0
# 59371   Roberto Dueas Hernndez   221.0  24.0   137.0
# 59372   Roberto Dueas Hernndez   221.0  28.0   137.0
# 207373   Arvydas Romas Sabonis   223.0  23.0   122.0

# %%
df.loc[df['Height']>220,['Height','Name','Age','Weight']].head()
# Out:
#         Height                    Name   Age  Weight
# 17669    221.0          Gunther Behnke  29.0   114.0
# 32376    223.0    Tommy Loren Burleson  20.0   102.0
# 59371    221.0  Roberto Dueas Hernndez  24.0   137.0
# 59372    221.0  Roberto Dueas Hernndez  28.0   137.0
# 207373   223.0   Arvydas Romas Sabonis  23.0   122.0

# %%
df[(df['Height']>190 ) & (df['NOC']=='IND')].head()
# Out:
#            ID                              Name Sex   Age  Height  Weight  \
# 6306     3539                    Vijay Amritraj   M  34.0   193.0    75.0
# 6307     3539                    Vijay Amritraj   M  34.0   193.0    75.0
# 22118   11651  Harishchandra Madhavrao Birajdar   M  22.0   192.0   100.0
# 39533   20341               Kynan Darius Chenai   M  25.0   200.0    85.0
# 116650  59022            Virdhawal Vikram Khade   M  16.0   191.0    83.0
#
#          Team  NOC        Games  Year  Season            City      Sport  \
# 6306    India  IND  1988 Summer  1988  Summer           Seoul     Tennis
# 6307    India  IND  1988 Summer  1988  Summer           Seoul     Tennis
# 22118   India  IND  1972 Summer  1972  Summer          Munich  Wrestling
# 39533   India  IND  2016 Summer  2016  Summer  Rio de Janeiro   Shooting
# 116650  India  IND  2008 Summer  2008  Summer         Beijing   Swimming
#
#                                           Event Medal
# ...

# %%
df[df['Team'].str.contains('India')].head()
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 505  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 505  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 506  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
#
#                                       Event Medal
# 505      Athletics Men's 110 metres Hurdles   NaN
# 506      Athletics Men's 400 metres Hurdles   NaN
# ...

# %%
df[df['Name'].str.contains(r'^kumar|kumr$',case=False,na=False)].head()
# Out:
#            ID             Name Sex   Age  Height  Weight   Team  NOC  \
# 10178    5563      Kumar Ashok   M  20.0   165.0    52.0  India  IND
# 11876    6469    Kumari Babita   F  26.0   165.0    52.0  India  IND
# 168630  84755  Kumar T. Navale   M   NaN     NaN     NaN  India  IND
#
#               Games  Year  Season            City      Sport  \
# 10178   1980 Summer  1980  Summer          Moskva  Wrestling
# 11876   2016 Summer  2016  Summer  Rio de Janeiro  Wrestling
# 168630  1920 Summer  1920  Summer       Antwerpen  Wrestling
#
#                                              Event Medal
# 10178         Wrestling Men's Flyweight, Freestyle   NaN
# 11876   Wrestling Women's Featherweight, Freestyle   NaN
# 168630     Wrestling Men's Middleweight, Freestyle   NaN

# %%
df[df['Name'].str.contains(r'^[AEIOUaeiou]*',case=False,na=False)].head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df[df['Name'].str.contains(r'[-]',case=False,na=False)].head()
# Out:
#     ID                                Name Sex   Age  Height  Weight  \
# 26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 34  14      Pirjo Hannele Aalto (Mattila-)   F  32.0   171.0    65.0
# 87  26        Agnes Erika Aanonsen (-Eyde)   F  17.0   169.0    65.0
# 89  28                    Jan-Erik Aarberg   M  43.0   170.0    77.0
#
#            Team  NOC        Games  Year  Season         City      Sport  \
# 26  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles  Athletics
# 27  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles  Athletics
# 34      Finland  FIN  1994 Winter  1994  Winter  Lillehammer   Biathlon
# 87       Norway  NOR  1984 Winter  1984  Winter     Sarajevo       Luge
# 89       Norway  NOR  1968 Summer  1968  Summer  Mexico City    Sailing
#
#                                      Event Medal
# 26            Athletics Women's 100 metres   NaN
# ...

# %%
df[df['Name'].str.contains(r'^.{7}$',case=False,na=False)].head(5)
# Out:
#         ID     Name Sex   Age  Height  Weight                  Team  NOC  \
# 1351   766  Ji Adam   M  25.0   187.0    83.0        Czechoslovakia  TCH
# 1352   766  Ji Adam   M  25.0   187.0    83.0        Czechoslovakia  TCH
# 1353   766  Ji Adam   M  29.0   187.0    83.0        Czechoslovakia  TCH
# 4694  2671  Ben Ali   M   NaN     NaN     NaN  United Arab Republic  UAR
# 4872  2780  Alkindi   M  26.0   190.0    60.0             Indonesia  INA
#
#             Games  Year  Season      City              Sport  \
# 1351  1976 Summer  1976  Summer  Montreal  Modern Pentathlon
# 1352  1976 Summer  1976  Summer  Montreal  Modern Pentathlon
# 1353  1980 Summer  1980  Summer    Moskva            Fencing
# 4694  1960 Summer  1960  Summer      Roma          Wrestling
# 4872  1988 Summer  1988  Summer     Seoul            Fencing
#
#                                           Event   Medal
# 1351         Modern Pentathlon Men's Individual     NaN
# ...

# %%
df[df['Medal']==df['Medal'].count()]
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal]
# Index: []

# %%
df.groupby('Medal')['Name'].count()
# Out:
# Medal
# Bronze    13295
# Gold      13372
# Silver    13116
# Name: Name, dtype: int64

# %%
df[df['Season'].isin(['Summer']) &(df['Name'].str.contains("son"))].head()
# Out:
#       ID                             Name Sex   Age  Height  Weight    Team  \
# 95    32             Olav Augunson Aarnes   M  23.0     NaN     NaN  Norway
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0   India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0   India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0   India
# 898  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0   India
#
#      NOC        Games  Year  Season         City      Sport  \
# 95   NOR  1912 Summer  1912  Summer    Stockholm  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
# 898  IND  1988 Summer  1988  Summer        Seoul  Athletics
#
#                                       Event Medal
# 95                Athletics Men's High Jump   NaN
# ...
