# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'./datasets/ipl-matches.csv')

# %%
m =pd.read_csv(r'./datasets/movies.csv')

# %%
m.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 m.info()
#
# AttributeError: 'NoneType' object has no attribute 'info'

# %%
df.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %% [markdown]
# final match winner all

# %%
final =df[df['MatchNumber']=='Final']

# %%
final[['WinningTeam','Season']]
# Out:
#                WinningTeam   Season
# 0           Gujarat Titans     2022
# 74     Chennai Super Kings     2021
# 134         Mumbai Indians  2020/21
# 194         Mumbai Indians     2019
# 254    Chennai Super Kings     2018
# 314         Mumbai Indians     2017
# 373    Sunrisers Hyderabad     2016
# 433         Mumbai Indians     2015
# 492  Kolkata Knight Riders     2014
# 552         Mumbai Indians     2013
# 628  Kolkata Knight Riders     2012
# 702    Chennai Super Kings     2011
# 775    Chennai Super Kings  2009/10
# 835        Deccan Chargers     2009
# 892       Rajasthan Royals  2007/08

# %% [markdown]
# how many superover finishes have occured

# %%
df['SuperOver'].value_counts()
# Out:
# SuperOver
# N    932
# Y     14
# Name: count, dtype: int64

# %% [markdown]
# csk win in kolkata

# %%
csk =df[df['WinningTeam']=='Chennai Super Kings'].count()

# %%
df[(df['WinningTeam']=='Chennai Super Kings') & (df['City']=='Kolkata')].head()
# Out:
#           ID     City        Date   Season MatchNumber                  Team1  \
# 224  1178404  Kolkata  2019-04-14     2019          29  Kolkata Knight Riders
# 602   598022  Kolkata  2013-04-20     2013          26  Kolkata Knight Riders
# 641   548368  Kolkata  2012-05-14     2012          63  Kolkata Knight Riders
# 827   419113  Kolkata  2010-03-16  2009/10           8  Kolkata Knight Riders
# 908   336025  Kolkata  2008-05-18  2007/08          41  Kolkata Knight Riders
#
#                    Team2         Venue             TossWinner TossDecision  \
# 224  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 602  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
# 641  Chennai Super Kings  Eden Gardens    Chennai Super Kings        field
# 827  Chennai Super Kings  Eden Gardens    Chennai Super Kings          bat
# 908  Chennai Super Kings  Eden Gardens  Kolkata Knight Riders          bat
#
# ...

# %%
df[df['WinningTeam'] ==df['TossWinner']].shape[0]/df.shape[0]*100.
# Out:
# 51.473684210526315

# %%
df[df['WinningTeam'] ==df['TossWinner']].plot(kind='barh')
# Out:
# <Axes: >

# %%
m[(m['imdb_rating']>8) & (m['imdb_votes']>10000)].tail(1)
# Out:
#              title_x    imdb_id  \
# 1571  Dil Chahta Hai  tt0292490
#
#                                             poster_path  \
# 1571  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                          wiki_link         title_y  \
# 1571  https://en.wikipedia.org/wiki/Dil_Chahta_Hai  Dil Chahta Hai
#
#       original_title  is_adult  year_of_release runtime                genres  \
# 1571  Dil Chahta Hai         0             2001     183  Comedy|Drama|Romance
#
#       imdb_rating  imdb_votes  \
# 1571          8.1       62313
#
#                                                   story  \
# 1571  Three young men Akash  Sameer  and Siddharth a...
#
#                                                 summary  \
# 1571  Three inseparable childhood friends are just o...
#
#                                                 tagline  \
# 1571  Welcome to a summer of their lives you will ne...
#
#                                                  actors  \
# ...

# %%
m[(m['imdb_rating']>8) & (m['imdb_votes']>10000)].tail(2)
# Out:
#              title_x    imdb_id  \
# 1568          Lagaan  tt0169102
# 1571  Dil Chahta Hai  tt0292490
#
#                                             poster_path  \
# 1568  https://upload.wikimedia.org/wikipedia/en/thum...
# 1571  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1568  https://en.wikipedia.org/wiki/Lagaan:_Once_Upo...
# 1571       https://en.wikipedia.org/wiki/Dil_Chahta_Hai
#
#                                 title_y                     original_title  \
# 1568  Lagaan: Once Upon a Time in India  Lagaan: Once Upon a Time in India
# 1571                     Dil Chahta Hai                     Dil Chahta Hai
#
#       is_adult  year_of_release runtime                   genres  imdb_rating  \
# 1568         0             2001     224  Adventure|Drama|Musical          8.1
# 1571         0             2001     183     Comedy|Drama|Romance          8.1
#
# ...

# %% [markdown]
# action movies with rating 7.5

# %%
def act(x):
    accc = x.split("|")
    return 'Action' in accc;

# %%
m[(m['genres'].apply(act)) &(m['imdb_rating']>7.5)].head(3)
# Out:
#                      title_x    imdb_id  \
# 0   Uri: The Surgical Strike  tt8291224
# 41      Family of Thakurganj  tt8897986
# 84                 Mukkabaaz  tt7180544
#
#                                           poster_path  \
# 0   https://upload.wikimedia.org/wikipedia/en/thum...
# 41  https://upload.wikimedia.org/wikipedia/en/9/99...
# 84  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                             wiki_link  \
# 0   https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 41  https://en.wikipedia.org/wiki/Family_of_Thakur...
# 84            https://en.wikipedia.org/wiki/Mukkabaaz
#
#                      title_y            original_title  is_adult  \
# 0   Uri: The Surgical Strike  Uri: The Surgical Strike         0
# 41      Family of Thakurganj      Family of Thakurganj         0
# 84               The Brawler                 Mukkabaaz         0
#
#     year_of_release runtime              genres  imdb_rating  imdb_votes  \
# ...

# %%
m['country']='INDIA'

# %%
def actor(x):
    accc = x.split("|")
    return accc[0]

# %%
m =m.dropna(inplace=True)

# %%
def actor(x):
    accc = x.split("|")
    return accc[0]

# %%
m.fillna(method='ffill',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 m.fillna(method='ffill',inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'fillna'

# %%
m['actors'].apply(actor)
# Out:
# 0          Vicky Kaushal
# 1            Vicky Ahuja
# 2            Anupam Kher
# 3          Emraan Hashmi
# 4       Mona Ambegaonkar
#               ...
# 1624          Ajay Devgn
# 1625       Ameesha Patel
# 1626         Vijay Arora
# 1627        Gippy Grewal
# 1628          Fawad Khan
# Name: actors, Length: 1629, dtype: object

# %%
m['release_date'].str.split("(").apply(lambda x:x[0])
# Out:
# 0        11 January 2019
# 1        11 January 2019
# 2        11 January 2019
# 3        18 January 2019
# 4        11 January 2019
#               ...
# 1624     7 November 2001
# 1625    16 November 2001
# 1626    16 November 2001
# 1627     1 November 2019
# 1628           TV Series
# Name: release_date, Length: 1629, dtype: object
