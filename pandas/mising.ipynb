# %% [markdown]
# mising data

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('student.csv')

# %%
df.head()
# Out:
#   student_id first_name   age gender  grade  math_score  english_score  \
# 0      S1000        Joy  19.0   Male    9.0        61.0           73.0
# 1      S1001      Donna  18.0    NaN   12.0        54.0           52.0
# 2      S1002        NaN  17.0   Male    NaN        43.0           98.0
# 3      S1003    Matthew  15.0   Male   10.0        65.0           42.0
# 4      S1004      David  19.0    NaN   12.0         NaN           94.0
#
#    attendance_percentage                   email               city
# 0                  60.37    sharon52@example.com         Port James
# 1                  87.91                     NaN  New Frederickfort
# 2                    NaN  cookbrandi@example.net                NaN
# 3                  69.35                     NaN      Harringtonton
# 4                  83.86   gcampbell@example.com      North Charles

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   student_id             44 non-null     object
#  1   first_name             42 non-null     object
#  2   age                    42 non-null     float64
#  3   gender                 42 non-null     object
#  4   grade                  44 non-null     float64
#  5   math_score             41 non-null     float64
#  6   english_score          43 non-null     float64
#  7   attendance_percentage  42 non-null     float64
#  8   email                  43 non-null     object
#  9   city                   44 non-null     object
# dtypes: float64(5), object(5)
# memory usage: 4.0+ KB

# %%
df.isna().tail()
# Out:
#     student_id  first_name    age  gender  grade  math_score  english_score  \
# 45       False        True  False   False  False       False          False
# 46       False        True  False    True  False       False          False
# 47       False       False   True   False  False        True          False
# 48        True        True  False   False  False       False          False
# 49       False       False  False   False  False       False          False
#
#     attendance_percentage  email   city
# 45                  False  False  False
# 46                  False   True  False
# 47                  False  False  False
# 48                   True  False  False
# 49                  False   True  False

# %%
df.isna().sum()
# Out:
# student_id               6
# first_name               8
# age                      8
# gender                   8
# grade                    6
# math_score               9
# english_score            7
# attendance_percentage    8
# email                    7
# city                     6
# dtype: int64

# %%
df.isna().any()
# Out:
# student_id               True
# first_name               True
# age                      True
# gender                   True
# grade                    True
# math_score               True
# english_score            True
# attendance_percentage    True
# email                    True
# city                     True
# dtype: bool

# %%
df.head()
# Out:
#   student_id first_name   age gender  grade  math_score  english_score  \
# 0      S1000        Joy  19.0   Male    9.0        61.0           73.0
# 1      S1001      Donna  18.0    NaN   12.0        54.0           52.0
# 2      S1002        NaN  17.0   Male    NaN        43.0           98.0
# 3      S1003    Matthew  15.0   Male   10.0        65.0           42.0
# 4      S1004      David  19.0    NaN   12.0         NaN           94.0
#
#    attendance_percentage                   email               city
# 0                  60.37    sharon52@example.com         Port James
# 1                  87.91                     NaN  New Frederickfort
# 2                    NaN  cookbrandi@example.net                NaN
# 3                  69.35                     NaN      Harringtonton
# 4                  83.86   gcampbell@example.com      North Charles

# %%
df.dropna()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 0       S1000        Joy  19.0    Male    9.0        61.0           73.0
# 5       S1005       John  19.0    Male   11.0        75.0           43.0
# 10      S1010       Ryan  17.0  Female   10.0        65.0           48.0
# 11      S1011    Barbara  21.0    Male   12.0        74.0           55.0
# 13      S1013   Jennifer  18.0  Female   11.0        92.0           88.0
# 14      S1014      Kelly  16.0    Male   11.0        53.0           41.0
# 19      S1019      Diane  19.0    Male    9.0        43.0           93.0
# 20      S1020     Sheila  18.0    Male   12.0        68.0           40.0
# 23      S1023    Michael  20.0    Male   10.0        61.0           47.0
# 25      S1025   Benjamin  16.0    Male   11.0        41.0           44.0
# 29      S1029   Kristine  15.0    Male    9.0        58.0           62.0
# 33      S1033       Cody  18.0    Male   10.0        44.0           55.0
# ...

# %%
df.dropna(thresh=8).tail()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 43      S1043      Barry  18.0  Female    9.0        46.0            NaN
# 44      S1044      Katie  21.0  Female   11.0        89.0           56.0
# 45      S1045        NaN  18.0    Male   12.0        60.0           95.0
# 47      S1047       Tara   NaN  Female   10.0         NaN           91.0
# 49      S1049   Geoffrey  20.0    Male   12.0        84.0           46.0
#
#     attendance_percentage                         email              city
# 43                    NaN  rasmussenphillip@example.net  Lake Alexismouth
# 44                  81.65         graysusan@example.org    Rasmussenshire
# 45                  63.64      butlerashley@example.com      Edwardshaven
# 47                  86.56      angelagarcia@example.com    Elizabethmouth
# 49                  82.84                           NaN   North Juliefurt

# %%
df.dropna(thresh=10).head()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 0       S1000        Joy  19.0    Male    9.0        61.0           73.0
# 5       S1005       John  19.0    Male   11.0        75.0           43.0
# 10      S1010       Ryan  17.0  Female   10.0        65.0           48.0
# 11      S1011    Barbara  21.0    Male   12.0        74.0           55.0
# 13      S1013   Jennifer  18.0  Female   11.0        92.0           88.0
#
#     attendance_percentage                    email             city
# 0                   60.37     sharon52@example.com       Port James
# 5                   97.13     curtis60@example.net  West Susanmouth
# 10                  72.04  williecantu@example.net    New Scottbury
# 11                  76.24    anthony33@example.com   South Paulside
# 13                  73.26      brian29@example.com      South Karen

# %% [markdown]
# filling the mixing values

# %%
df.fillna(0).tail()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 45      S1045          0  18.0    Male   12.0        60.0           95.0
# 46      S1046          0  19.0       0   12.0        42.0           52.0
# 47      S1047       Tara   0.0  Female   10.0         0.0           91.0
# 48          0          0  18.0    Male    9.0        51.0           89.0
# 49      S1049   Geoffrey  20.0    Male   12.0        84.0           46.0
#
#     attendance_percentage                     email                 city
# 45                  63.64  butlerashley@example.com         Edwardshaven
# 46                  89.72                         0       Port Brentfort
# 47                  86.56  angelagarcia@example.com       Elizabethmouth
# 48                   0.00   keithgarcia@example.net  Port Elizabethburgh
# 49                  82.84                         0      North Juliefurt

# %%
val = {'student_id':1,'first_name':"mack",'age':50,'gender':'male','grade':10.0,'math_score':50.0,'english_score':50.0,'attendance_percentage':80,'email':"abc@1","city":'none'}

# %%
df.fillna(value=val)
df.tail()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 45      S1045        NaN  18.0    Male   12.0        60.0           95.0
# 46      S1046        NaN  19.0     NaN   12.0        42.0           52.0
# 47      S1047       Tara   NaN  Female   10.0         NaN           91.0
# 48        NaN        NaN  18.0    Male    9.0        51.0           89.0
# 49      S1049   Geoffrey  20.0    Male   12.0        84.0           46.0
#
#     attendance_percentage                     email                 city
# 45                  63.64  butlerashley@example.com         Edwardshaven
# 46                  89.72                       NaN       Port Brentfort
# 47                  86.56  angelagarcia@example.com       Elizabethmouth
# 48                    NaN   keithgarcia@example.net  Port Elizabethburgh
# 49                  82.84                       NaN      North Juliefurt

# %%
df.isna().any()
# Out:
# student_id               True
# first_name               True
# age                      True
# gender                   True
# grade                    True
# math_score               True
# english_score            True
# attendance_percentage    True
# email                    True
# city                     True
# dtype: bool

# %%
df.tail()
# Out:
#    student_id first_name   age  gender  grade  math_score  english_score  \
# 45      S1045        NaN  18.0    Male   12.0        60.0           95.0
# 46      S1046        NaN  19.0     NaN   12.0        42.0           52.0
# 47      S1047       Tara   NaN  Female   10.0         NaN           91.0
# 48        NaN        NaN  18.0    Male    9.0        51.0           89.0
# 49      S1049   Geoffrey  20.0    Male   12.0        84.0           46.0
#
#     attendance_percentage                     email                 city
# 45                  63.64  butlerashley@example.com         Edwardshaven
# 46                  89.72                       NaN       Port Brentfort
# 47                  86.56  angelagarcia@example.com       Elizabethmouth
# 48                    NaN   keithgarcia@example.net  Port Elizabethburgh
# 49                  82.84                       NaN      North Juliefurt

# %%
fdf =df.fillna(method='ffill').tail()
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_1324\72938894.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   fdf =df.fillna(method='ffill').tail()

# %%
bf =df.fillna(method='bfill').head()
# Out:
# C:\Users\karli\AppData\Local\Temp\ipykernel_1324\2143820533.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   bf =df.fillna(method='bfill').head()

# %%
bf.head()
# Out:
#   student_id first_name   age gender  grade  math_score  english_score  \
# 0      S1000        Joy  19.0   Male    9.0        61.0           73.0
# 1      S1001      Donna  18.0   Male   12.0        54.0           52.0
# 2      S1002    Matthew  17.0   Male   10.0        43.0           98.0
# 3      S1003    Matthew  15.0   Male   10.0        65.0           42.0
# 4      S1004      David  19.0   Male   12.0        75.0           94.0
#
#    attendance_percentage                   email               city
# 0                  60.37    sharon52@example.com         Port James
# 1                  87.91  cookbrandi@example.net  New Frederickfort
# 2                  69.35  cookbrandi@example.net      Harringtonton
# 3                  69.35   gcampbell@example.com      Harringtonton
# 4                  83.86   gcampbell@example.com      North Charles

# %%
df.head()
# Out:
#   student_id first_name   age gender  grade  math_score  english_score  \
# 0      S1000        Joy  19.0   Male    9.0        61.0           73.0
# 1      S1001      Donna  18.0    NaN   12.0        54.0           52.0
# 2      S1002        NaN  17.0   Male    NaN        43.0           98.0
# 3      S1003    Matthew  15.0   Male   10.0        65.0           42.0
# 4      S1004      David  19.0    NaN   12.0         NaN           94.0
#
#    attendance_percentage                   email               city
# 0                  60.37    sharon52@example.com         Port James
# 1                  87.91                     NaN  New Frederickfort
# 2                    NaN  cookbrandi@example.net                NaN
# 3                  69.35                     NaN      Harringtonton
# 4                  83.86   gcampbell@example.com      North Charles

# %%
fil = df.fillna(df.loc[:,['math_score','english_score','age','attendance_percentage']].mean())

# %%
fil
# Out:
#    student_id   first_name        age  gender  grade  math_score  \
# 0       S1000          Joy  19.000000    Male    9.0   61.000000
# 1       S1001        Donna  18.000000     NaN   12.0   54.000000
# 2       S1002          NaN  17.000000    Male    NaN   43.000000
# 3       S1003      Matthew  15.000000    Male   10.0   65.000000
# 4       S1004        David  19.000000     NaN   12.0   65.121951
# 5       S1005         John  19.000000    Male   11.0   75.000000
# 6         NaN         Leah  19.000000    Male   10.0   55.000000
# 7       S1007      Heather  20.000000    Male    9.0   61.000000
# 8         NaN        Tyler  16.000000  Female   11.0   71.000000
# 9         NaN        Jenna  21.000000     NaN   10.0   58.000000
# 10      S1010         Ryan  17.000000  Female   10.0   65.000000
# 11      S1011      Barbara  21.000000    Male   12.0   74.000000
# 12      S1012      Melinda  18.428571  Female   12.0   54.000000
# ...

# %%
fil.isna().any()
# Out:
# student_id                True
# first_name                True
# age                      False
# gender                    True
# grade                     True
# math_score               False
# english_score            False
# attendance_percentage    False
# email                     True
# city                      True
# dtype: bool

# %%
fil.loc[:,['first_name']].head()
# Out:
#   first_name
# 0        Joy
# 1      Donna
# 2        NaN
# 3    Matthew
# 4      David
