# %%
import numpy as np
import  pandas as pd
import matplotlib.pyplot as plt
import seaborn as sna

# %%
df = pd.read_csv('./datasets/exercise.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_id              15000 non-null  object
#  1   user_id               15000 non-null  object
#  2   driver_id             15000 non-null  object
#  3   product_type          15000 non-null  object
#  4   city                  15000 non-null  object
#  5   zone                  15000 non-null  object
#  6   lat                   15000 non-null  float64
#  7   lon                   15000 non-null  float64
#  8   request_time          15000 non-null  object
#  9   driver_accept_time    15000 non-null  object
#  10  pickup_time           14416 non-null  object
#  11  dropoff_time          13816 non-null  object
#  12  status                15000 non-null  object
#  13  vehicle_type          15000 non-null  object
#  14  payment_method        15000 non-null  object
# ...

# %%
df.shape
# Out:
# (15000, 35)

# %%
df.isna().any()
# Out:
# order_id                False
# user_id                 False
# driver_id               False
# product_type            False
# city                    False
# zone                    False
# lat                     False
# lon                     False
# request_time            False
# driver_accept_time      False
# pickup_time              True
# dropoff_time             True
# status                  False
# vehicle_type            False
# payment_method          False
# surge_multiplier        False
# estimated_fare          False
# actual_fare              True
# distance_km             False
# duration_min             True
# wait_min                False
# rating                   True
# coupon_applied          False
# temperature_c           False
# precipitation_mm        False
# is_weekend              False
# traffic_index           False
# device_type             False
# app_version_major       False
# referral_source         False
# surge_hour              False
# ...

# %%
df.describe()
# Out:
#                 lat           lon  surge_multiplier  estimated_fare  \
# count  15000.000000  15000.000000      15000.000000    15000.000000
# mean      19.385534     77.604821          1.191670      100.977309
# std        4.934750      4.785609          0.193352       40.748727
# min       12.804800     72.406530          1.000000       22.100000
# 25%       17.235425     73.765335          1.000000       72.760000
# 50%       18.601885     77.232580          1.150000       93.270000
# 75%       22.664925     78.568815          1.320000      120.890000
# max       28.881530     88.518280          2.270000      542.550000
#
#         actual_fare   distance_km  duration_min      wait_min        rating  \
# count  13816.000000  15000.000000  13816.000000  15000.000000  13816.000000
# mean     103.172237      4.003532     15.403518      6.308258      4.346562
# std       41.217604      2.649551     10.342914      5.236732      0.519656
# ...

# %% [markdown]
# now plot some dataframe pandas plot

# %%
df.plot(kind='hist',edgecolor='black',figsize=(6,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df
# Out:
#          order_id     user_id   driver_id product_type       city     zone  \
# 0      ORD_000001  USR_005239  DRV_000913         Ride    Chennai    South
# 1      ORD_000002  USR_000245  DRV_000768         Ride     Mumbai  Central
# 2      ORD_000003  USR_000054  DRV_001308         Ride       Pune     East
# 3      ORD_000004  USR_002818  DRV_004946         Ride     Mumbai     West
# 4      ORD_000005  USR_005067  DRV_002963         Ride      Delhi    North
# ...           ...         ...         ...          ...        ...      ...
# 14995  ORD_014996  USR_000828  DRV_000021     Delivery    Kolkata    South
# 14996  ORD_014997  USR_000581  DRV_003629     Delivery     Mumbai    South
# 14997  ORD_014998  USR_002343  DRV_002042     Delivery     Mumbai  Central
# 14998  ORD_014999  USR_001793  DRV_003337         Ride    Chennai  Central
# 14999  ORD_015000  USR_002104  DRV_002060         Ride  Hyderabad     East
#
#             lat       lon                request_time  \
# ...

# %%
df[['city','lon']].plot(kind='hist',edgecolor='navy',color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# line plot

# %%
dff=df.head(50)

# %%
dff[['lat','lon','actual_fare']].plot(kind='line',subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
dff[['actual_fare','distance_km']].plot(kind='line')
# Out:
# <Axes: >

# %%
dff
# Out:
#       order_id     user_id   driver_id product_type       city     zone  \
# 0   ORD_000001  USR_005239  DRV_000913         Ride    Chennai    South
# 1   ORD_000002  USR_000245  DRV_000768         Ride     Mumbai  Central
# 2   ORD_000003  USR_000054  DRV_001308         Ride       Pune     East
# 3   ORD_000004  USR_002818  DRV_004946         Ride     Mumbai     West
# 4   ORD_000005  USR_005067  DRV_002963         Ride      Delhi    North
# 5   ORD_000006  USR_003114  DRV_002278         Ride       Pune    South
# 6   ORD_000007  USR_005974  DRV_002006         Ride  Ahmedabad     East
# 7   ORD_000008  USR_001877  DRV_000263     Delivery  Ahmedabad     East
# 8   ORD_000009  USR_000745  DRV_000386     Delivery  Bengaluru    South
# 9   ORD_000010  USR_002060  DRV_004533     Delivery     Mumbai    North
# 10  ORD_000011  USR_000027  DRV_002158     Delivery  Bengaluru  Central
# 11  ORD_000012  USR_004419  DRV_004345     Delivery       Pune     West
# ...

# %% [markdown]
# count highest payment done by which method per vechicle

# %%
method =df.groupby('vehicle_type')['payment_method'].count()

# %%
method.plot(kind='bar',subplots= True)
# Out:
# array([<Axes: title={'center': 'payment_method'}, xlabel='vehicle_type'>],
#       dtype=object)

# %%
method =df.groupby('vehicle_type')[['rating']].count()

# %%
method
# Out:
#               rating
# vehicle_type
# Auto            3383
# Bike            2063
# Mini Truck      1415
# SUV             2820
# Sedan           4135

# %%
dff['estimated_fare'].plot(kind='bar',x='zone',color='navy',)
# Out:
# <Axes: >

# %%
df.plot(kind='scatter',x='actual_fare',y='estimated_fare',
title='actual vs estimated price',color='#31C950',figsize=(5,4),s='distance_km')
# Out:
# <Axes: title={'center': 'actual vs estimated price'}, xlabel='actual_fare', ylabel='estimated_fare'>
