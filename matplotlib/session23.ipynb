# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-v0_8-whitegrid")

# plt.style.use("tableau-colorblind10")

# %% [markdown]
# 2d plot

# %%
price =[]
year =[]

# %%
price = np.random.randint(8000, 8600, size=10)   # 10 random numbers between 1–100
year = np.random.randint(2023, 2026, size=10) # Random years between 2000–2024

df = pd.DataFrame({
    "price": price,
    "year": year
})

# %%
df.head(5)
# Out:
#    price  year
# 0   8191  2024
# 1   8045  2023
# 2   8452  2024
# 3   8304  2023
# 4   8370  2025

# %%
plt.plot(df['year'],df['price'],color='black')

# %%
year=[5658,8694,6866,2000,444]
price=[2012,2014,2015,2016,2019]
plt.plot(year,price)

# %%
bat = pd.read_csv('./datasets/sharma-kohli.csv')

# %%
bat.shape
# Out:
# (10, 3)

# %%
bat.head(5)
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#E7180B')
plt.plot(bat['index'],bat['V Kohli'],color='#2AA63E')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#0A0C0F',linestyle='dashed',linewidth=3.9)
plt.plot(bat['index'],bat['V Kohli'],color='#737373',linestyle='solid',linewidth=1.6)
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#A30000",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#0DFE35",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %% [markdown]
# label

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#7501E86D",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#000000",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
plt.legend(loc='best')

# %%
# plt.Figure(10*6)
price=[5658,8694,6866,2000,44400]
year=[2012,2014,2015,2016,2017]
plt.plot(year,price)
plt.ylim(5000,20000)
plt.xlim(2015,2017)
plt.show()

# %%
bat
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="red",linestyle='dashed',linewidth=1.6,marker='D',markersize=5.9,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color='green',linestyle='dotted',linewidth=1,marker='D',markersize=6,label='virat')
plt.legend()
plt.title("custom printing")
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# scatterplot

# %%
x = np.linspace(-10,10,200)
x
y = 10*x +30 + np.random.randint(0,500,200);
y
# Out:
# array([341.        , -34.99497487, 364.01005025, 194.01507538,
#        131.0201005 ,  83.02512563,  38.03015075,  42.03517588,
#        146.04020101, -32.95477387, 399.05025126, 343.05527638,
#        303.06030151, 331.06532663, -45.92964824, 191.07537688,
#        407.08040201, 347.08542714, 116.09045226, -41.90452261,
#        176.10050251,  44.10552764, 440.11055276, 168.11557789,
#        278.12060302, 273.12562814, 168.13065327,  81.13567839,
#        248.14070352,  77.14572864, 285.15075377, 406.15577889,
#         45.16080402, 220.16582915, 257.17085427,  56.1758794 ,
#         32.18090452, 123.18592965, 386.19095477, 109.1959799 ,
#        262.20100503, 334.20603015,  76.21105528, 179.2160804 ,
#        367.22110553,  87.22613065, 297.23115578, 108.2361809 ,
#        212.24120603, 100.24623116,  94.25125628,  33.25628141,
#        460.26130653, 444.26633166, 112.27135678, 110.27638191,
#        190.28140704,  27.28643216, 140.29145729, 477.29648241,
#         57.30150754, 474.30653266, 390.31155779,  22.31658291,
#        197.32160804, 482.32663317, 315.33165829, 293.33668342,
#        198.34170854, 128.34673367, 479.35175879,  27.35678392,
#        412.36180905, 138.36683417, 332.3718593 , 202.37688442,
#        475.38190955, 474.38693467, 158.3919598 , 231.39698492,
#        197.40201005, 174.40703518, 316.4120603 ,  23.41708543,
#        104.42211055, 292.42713568, 302.4321608 ,  39.43718593,
#        248.44221106, 232.44723618, 332.45226131, 229.45728643,
#        182.46231156, 281.46733668, 100.47236181, 510.47738693,
#        482.48241206, 276.48743719, 382.49246231, 196.49748744,
#        506.50251256, 171.50753769, 239.51256281, 417.51758794,
#        103.52261307, 410.52763819, 330.53266332, 254.53768844,
#        159.54271357, 385.54773869, 449.55276382, 155.55778894,
#        511.56281407, 284.5678392 , 406.57286432, 494.57788945,
#        180.58291457, 323.5879397 , 514.59296482, 200.59798995,
#        279.60301508, 172.6080402 , 458.61306533,  89.61809045,
#        504.62311558, 182.6281407 , 385.63316583, 464.63819095,
#        113.64321608, 112.64824121, 455.65326633, 306.65829146,
#        317.66331658, 159.66834171, 494.67336683, 313.67839196,
#        462.68341709, 306.68844221, 500.69346734, 213.69849246,
#        520.70351759, 238.70854271, 435.71356784, 412.71859296,
#        388.72361809, 454.72864322, 160.73366834, 231.73869347,
#        147.74371859, 443.74874372, 235.75376884, 354.75879397,
#        448.7638191 , 288.76884422, 557.77386935, 123.77889447,
#        168.7839196 , 235.78894472, 436.79396985, 113.79899497,
#        429.8040201 , 280.80904523, 369.81407035, 514.81909548,
#        588.8241206 , 244.82914573, 237.83417085, 467.83919598,
#        259.84422111, 108.84924623, 246.85427136, 353.85929648,
#        280.86432161, 495.86934673, 457.87437186, 196.87939698,
#        421.88442211, 492.88944724, 576.89447236, 555.89949749,
#        327.90452261, 568.90954774, 270.91457286, 347.91959799,
#        586.92462312, 538.92964824, 475.93467337, 504.93969849,
#        467.94472362, 241.94974874, 543.95477387, 601.95979899,
#        508.96482412, 394.96984925, 343.97487437, 439.9798995 ,
#        292.98492462, 176.98994975, 398.99497487, 241.        ])

# %%
plt.scatter(x,y)

# %%
batter =pd.read_csv(r'./datasets/batter.csv')

# %%
batter.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
batter.shape
# Out:
# (605, 4)

# %%
df= batter.head(50)

# %%
plt.scatter(df['avg'],df['strike_rate'],color='green')
plt.title('avg and title analysis of top 50')
plt.xlabel('avg')
plt.ylabel('strike rate')
# Out:
# Text(0, 0.5, 'strike rate')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size'])

# %%
plt.plot(tips['total_bill'],tips['tip'],'o',color='#3BE61A')

# %% [markdown]
# bar chart

# %%
mark =[50,88,66,44,82,39,35,99,75,58]
name =['a','b','c','d','e','f','j','h','i','k']

# %%
plt.bar(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# horizontal bar

# %%
plt.barh(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
s = pd.read_csv('./datasets/bat_s.csv')

# %%
s
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(s['batsman'],s['2015'],color='yellow',width=0.1)
# Out:
# <BarContainer object of 5 artists>
