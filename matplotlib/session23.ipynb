# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use("seaborn-v0_8-whitegrid")
plt.style.use('ggplot')

# plt.style.use("tableau-colorblind10")

# %% [markdown]
# 2d plot

# %%
price =[]
year =[]

# %%
price = np.random.randint(8000, 8600, size=10)   # 10 random numbers between 1–100
year = np.random.randint(2023, 2026, size=10) # Random years between 2000–2024

df = pd.DataFrame({
    "price": price,
    "year": year
})

# %%
df.head(5)
# Out:
#    price  year
# 0   8177  2024
# 1   8058  2025
# 2   8074  2024
# 3   8577  2025
# 4   8436  2023

# %%
plt.plot(df['year'],df['price'],color='black')

# %%
year=[5658,8694,6866,2000,444]
price=[2012,2014,2015,2016,2019]
plt.plot(year,price)

# %%
bat = pd.read_csv('./datasets/sharma-kohli.csv')

# %%
bat.shape
# Out:
# (10, 3)

# %%
bat.head(5)
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#E7180B')
plt.plot(bat['index'],bat['V Kohli'],color='#2AA63E')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#0A0C0F',linestyle='dashed',linewidth=3.9)
plt.plot(bat['index'],bat['V Kohli'],color='#737373',linestyle='solid',linewidth=1.6)
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#A30000",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#0DFE35",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %% [markdown]
# label

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#7501E86D",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#000000",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
plt.legend(loc='best')

# %%
# plt.Figure(10*6)
price=[5658,8694,6866,2000,44400]
year=[2012,2014,2015,2016,2017]
plt.plot(year,price)
plt.ylim(5000,20000)
plt.xlim(2015,2017)
plt.show()

# %%
bat
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="red",linestyle='dashed',linewidth=1.6,marker='D',markersize=5.9,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color='green',linestyle='dotted',linewidth=1,marker='D',markersize=6,label='virat')
plt.legend()
plt.title("custom printing")
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# scatterplot

# %%
x = np.linspace(-10,10,200)
x
y = 10*x +30 + np.random.randint(0,500,200);
y
# Out:
# array([-34.        , 283.00502513, 233.01005025, 148.01507538,
#        237.0201005 ,  38.02512563, 286.03015075, 123.03517588,
#        310.04020101, -46.95477387, 213.05025126, -25.94472362,
#        303.06030151, -41.93467337, 135.07035176, 213.07537688,
#        320.08040201, 215.08542714,  54.09045226,  68.09547739,
#        -34.89949749,  94.10552764,  53.11055276, 382.11557789,
#        130.12060302, 273.12562814, 408.13065327, 407.13567839,
#        294.14070352,  83.14572864, 221.15075377, 448.15577889,
#        201.16080402, 409.16582915, 428.17085427, 411.1758794 ,
#        118.18090452, 100.18592965, 270.19095477, 198.1959799 ,
#          3.20100503,  20.20603015, 422.21105528, 209.2160804 ,
#        367.22110553, 295.22613065,  62.23115578, 114.2361809 ,
#        289.24120603,  95.24623116, 339.25125628,  12.25628141,
#        304.26130653, 206.26633166, 307.27135678, 332.27638191,
#        272.28140704,  64.28643216,  27.29145729, 346.29648241,
#        331.30150754,  61.30653266, 448.31155779, 417.31658291,
#        316.32160804, 417.32663317, 302.33165829, 437.33668342,
#        287.34170854, 284.34673367, 252.35175879, 165.35678392,
#        183.36180905, 408.36683417,  77.3718593 , 262.37688442,
#        263.38190955, 278.38693467, 357.3919598 , 387.39698492,
#        364.40201005, 429.40703518, 495.4120603 , 157.41708543,
#        128.42211055,  76.42713568, 155.4321608 ,  78.43718593,
#        490.44221106, 185.44723618, 281.45226131, 257.45728643,
#         76.46231156,  66.46733668, 460.47236181, 318.47738693,
#        220.48241206,  62.48743719, 451.49246231, 197.49748744,
#        229.50251256,  36.50753769, 381.51256281, 269.51758794,
#        498.52261307, 324.52763819,  69.53266332, 488.53768844,
#        525.54271357, 278.54773869, 490.55276382, 433.55778894,
#        257.56281407, 135.5678392 , 470.57286432, 107.57788945,
#        404.58291457, 180.5879397 ,  58.59296482, 437.59798995,
#        463.60301508, 472.6080402 , 488.61306533, 357.61809045,
#        168.62311558, 346.6281407 , 377.63316583, 226.63819095,
#        177.64321608, 300.64824121, 401.65326633, 300.65829146,
#        381.66331658, 545.66834171, 530.67336683, 195.67839196,
#         92.68341709, 364.68844221, 231.69346734, 154.69849246,
#        379.70351759, 328.70854271, 354.71356784, 297.71859296,
#        472.72361809, 345.72864322, 449.73366834, 203.73869347,
#        315.74371859, 148.74874372, 396.75376884, 472.75879397,
#        345.7638191 , 296.76884422, 156.77386935, 444.77889447,
#        571.7839196 , 203.78894472, 495.79396985, 412.79899497,
#        301.8040201 , 190.80904523, 551.81407035, 324.81909548,
#        225.8241206 , 321.82914573, 209.83417085, 278.83919598,
#        459.84422111, 392.84924623, 237.85427136, 336.85929648,
#        412.86432161, 502.86934673, 405.87437186, 239.87939698,
#        600.88442211, 271.88944724, 215.89447236, 276.89949749,
#        220.90452261, 479.90954774, 142.91457286, 371.91959799,
#        216.92462312, 420.92964824, 425.93467337, 441.93969849,
#        158.94472362, 284.94974874, 300.95477387, 315.95979899,
#        126.96482412, 586.96984925, 323.97487437, 163.9798995 ,
#        126.98492462, 271.98994975, 294.99497487, 540.        ])

# %%
plt.scatter(x,y)

# %%
batter =pd.read_csv(r'./datasets/batter.csv')

# %%
batter.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
batter.shape
# Out:
# (605, 4)

# %%
df= batter.head(50)

# %%
plt.scatter(df['avg'],df['strike_rate'],color='green')
plt.title('avg and title analysis of top 50')
plt.xlabel('avg')
plt.ylabel('strike rate')
# Out:
# Text(0, 0.5, 'strike rate')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size'])

# %%
plt.plot(tips['total_bill'],tips['tip'],'o',color='#3BE61A')

# %% [markdown]
# bar chart

# %%
mark =[50,88,66,44,82,39,35,99,75,58]
name =['a','b','c','d','e','f','j','h','i','k']

# %%
plt.bar(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# horizontal bar

# %%
plt.barh(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
s = pd.read_csv('./datasets/bat_s.csv')

# %%
s
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(s['batsman'],s['2015'],color='yellow',width=0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
s.shape
# Out:
# (5, 4)

# %%
np.arange(s.shape[0])
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# multiple bar plot

# %%
plt.bar(np.arange(s.shape[0])-0.2,s['2015'],width=0.2,color='#90E31C')
plt.bar(np.arange(s.shape[0]),s['2016'],width=0.2,color='#E7180B')
plt.bar(np.arange(s.shape[0])+0.2,s['2017'],width=0.2,color='#23AFA1')
plt.xticks(np.arange(s.shape[0]),s['batsman'])
plt.show()

# %%
plt.barh(np.arange(s.shape[0])-0.2,s['2015'],height=0.2,color='#23AFA1')
plt.barh(np.arange(s.shape[0]),s['2016'],height=0.2,color='#0C0A09')
plt.barh(np.arange(s.shape[0])+0.2,s['2017'],height=0.2,color='#7512ED')
plt.yticks(np.arange(s.shape[0]),s['batsman'])
plt.show()

# %% [markdown]
# Stacked bar chart

# %%
s
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(s['batsman'],s['2017'],label='2017',color='#C81609',width=0.5,edgecolor='black')
plt.bar(s['batsman'],s['2016'],bottom=s['2017'],label='2016',color='#0E0C0B',width=0.5,edgecolor='black')
plt.bar(s['batsman'],s['2015'],bottom=(s['2016']+s['2017']),label='2015',color="#E7E7E7",width=0.5,edgecolor='black')
plt.legend()
plt.show()

# %% [markdown]
# histrogram

# %%
plt.hist(mark,bins=[35,50,80,90],color='purple',edgecolor='white')
# Out:
# (array([3., 4., 2.]),
#  array([35., 50., 80., 90.]),
#  <BarContainer object of 3 artists>)

# %%
vk = pd.read_csv('./datasets/vk.csv')

# %%
vk.head(5)
# Out:
#    match_id  batsman_runs
# 0        12            62
# 1        17            28
# 2        20            64
# 3        27             0
# 4        30            10

# %%
plt.hist(vk['batsman_runs'],bins=[0,10,20,40,50,70,90,100,120,130],color='green',edgecolor='black')
plt.show()

# %%
import numpy as np

arr = np.load("big_array.npy", mmap_mode='r')
print(arr.shape)
print(arr[0])  # Loads only the first row into memory
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[194], line 3
#       1 import numpy as np
# ----> 3 arr = np.load("big_array.npy", mmap_mode='r')
#       4 print(arr.shape)
#       5 print(arr[0])  # Loads only the first row into memory
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'big_array.npy'
