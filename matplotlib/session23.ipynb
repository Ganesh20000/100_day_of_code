# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use("seaborn-v0_8-whitegrid")
# plt.style.use('ggplot')
plt.style.use('seaborn-v0_8-muted')

# plt.style.use("tableau-colorblind10")

# %% [markdown]
# 2d plot

# %%
price =[]
year =[]

# %%
price = np.random.randint(8000, 8600, size=10)   # 10 random numbers between 1–100
year = np.random.randint(2023, 2026, size=10) # Random years between 2000–2024

df = pd.DataFrame({
    "price": price,
    "year": year
})

# %%
df.head(5)
# Out:
#    price  year
# 0   8412  2024
# 1   8378  2023
# 2   8222  2023
# 3   8587  2023
# 4   8040  2025

# %%
plt.plot(df['year'],df['price'],color='black')

# %%
year=[5658,8694,6866,2000,444]
price=[2012,2014,2015,2016,2019]
plt.plot(year,price)

# %%
bat = pd.read_csv('./datasets/sharma-kohli.csv')

# %%
bat.shape
# Out:
# (10, 3)

# %%
bat.head(5)
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364

# %%
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])

# %%
plt.plot(bat['index'],bat['RG Sharma'])
plt.plot(bat['index'],bat['V Kohli'])

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#E7180B')
plt.plot(bat['index'],bat['V Kohli'],color='#2AA63E')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color='#0A0C0F',linestyle='dashed',linewidth=3.9)
plt.plot(bat['index'],bat['V Kohli'],color='#737373',linestyle='solid',linewidth=1.6)
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#A30000",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#0DFE35",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
# Out:
# Text(0, 0.5, 'runs scoread')

# %% [markdown]
# label

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="#7501E86D",marker='D',markersize=3.5,linestyle='dashdot',linewidth=3.5,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color="#000000",marker='D',markersize=2.5,linestyle='dotted',linewidth=2.5,label='virat')
plt.title('rohit sharma vs virat kohi perfomance on run vs season ')
plt.xlabel('season')
plt.ylabel('runs scoread')
plt.legend(loc='best')

# %%
# plt.Figure(10*6)
price=[5658,8694,6866,2000,44400]
year=[2012,2014,2015,2016,2017]
plt.plot(year,price)
plt.ylim(5000,20000)
plt.xlim(2015,2017)
plt.show()

# %%
bat
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
plt.plot(bat['index'],bat['RG Sharma'],color="red",linestyle='dashed',linewidth=1.6,marker='D',markersize=5.9,label='rohit')
plt.plot(bat['index'],bat['V Kohli'],color='green',linestyle='dotted',linewidth=1,marker='D',markersize=6,label='virat')
plt.legend()
plt.title("custom printing")
plt.xlabel('year')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# scatterplot

# %%
x = np.linspace(-10,10,200)
x
y = 10*x +30 + np.random.randint(0,500,200);
y
# Out:
# array([339.        , 247.00502513, 287.01005025,  -4.98492462,
#        246.0201005 ,  12.02512563, 119.03015075,  55.03517588,
#        387.04020101,  70.04522613, 305.05025126, 120.05527638,
#        328.06030151,  47.06532663, 252.07035176, 408.07537688,
#         43.08040201, 152.08542714,  50.09045226, 446.09547739,
#        326.10050251, 183.10552764, 215.11055276, 368.11557789,
#        123.12060302, 241.12562814, 440.13065327,   7.13567839,
#        126.14070352, 371.14572864, 370.15075377,  34.15577889,
#        450.16080402, -36.83417085, 161.17085427, 178.1758794 ,
#        149.18090452, 120.18592965, 321.19095477, 207.1959799 ,
#        166.20100503, -13.79396985, 256.21105528, 270.2160804 ,
#        201.22110553, 159.22613065, 290.23115578, 264.2361809 ,
#         49.24120603, 129.24623116,  67.25125628, 272.25628141,
#        221.26130653, 445.26633166, 371.27135678, 187.27638191,
#        102.28140704, 112.28643216, 127.29145729, 151.29648241,
#        358.30150754, 490.30653266, 466.31155779,  72.31658291,
#        294.32160804, 282.32663317,  12.33165829, 170.33668342,
#        142.34170854, 117.34673367, 228.35175879, 356.35678392,
#        445.36180905, 158.36683417, 259.3718593 , 413.37688442,
#        366.38190955, 295.38693467, 259.3919598 , 283.39698492,
#         68.40201005, 195.40703518, 260.4120603 , 247.41708543,
#        100.42211055, 261.42713568, 396.4321608 , 161.43718593,
#        328.44221106, 452.44723618,  33.45226131, 136.45728643,
#         70.46231156, 344.46733668, 139.47236181, 496.47738693,
#         61.48241206, 383.48743719, 347.49246231, 116.49748744,
#        123.50251256, 145.50753769,  62.51256281, 267.51758794,
#        374.52261307, 238.52763819, 239.53266332, 357.53768844,
#        335.54271357, 408.54773869, 203.55276382, 173.55778894,
#        232.56281407, 277.5678392 , 257.57286432, 233.57788945,
#        184.58291457, 177.5879397 , 374.59296482, 129.59798995,
#        142.60301508,  94.6080402 , 133.61306533, 315.61809045,
#        511.62311558,  95.6281407 , 224.63316583, 420.63819095,
#        398.64321608, 192.64824121,  66.65326633, 460.65829146,
#        250.66331658, 548.66834171, 538.67336683, 243.67839196,
#        206.68341709, 187.68844221, 480.69346734, 249.69849246,
#        411.70351759, 264.70854271, 405.71356784, 517.71859296,
#        434.72361809, 478.72864322, 464.73366834, 481.73869347,
#        512.74371859, 246.74874372, 485.75376884, 575.75879397,
#        306.7638191 , 471.76884422, 212.77386935, 411.77889447,
#        282.7839196 , 484.78894472, 444.79396985, 244.79899497,
#        552.8040201 , 429.80904523, 155.81407035, 415.81909548,
#        476.8241206 , 261.82914573, 414.83417085, 512.83919598,
#        458.84422111, 196.84924623, 141.85427136, 305.85929648,
#        263.86432161, 185.86934673, 409.87437186, 128.87939698,
#        565.88442211, 378.88944724, 412.89447236, 194.89949749,
#        249.90452261, 331.90954774, 246.91457286, 130.91959799,
#        234.92462312, 474.92964824, 169.93467337, 132.93969849,
#        548.94472362, 348.94974874, 131.95477387, 349.95979899,
#        357.96482412, 539.96984925, 178.97487437, 612.9798995 ,
#        457.98492462, 570.98994975, 451.99497487, 134.        ])

# %%
plt.scatter(x,y)

# %%
batter =pd.read_csv(r'./datasets/batter.csv')

# %%
batter.head(3)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577

# %%
batter.shape
# Out:
# (605, 4)

# %%
df= batter.head(50)

# %%
plt.scatter(df['avg'],df['strike_rate'],color='green')
plt.title('avg and title analysis of top 50')
plt.xlabel('avg')
plt.ylabel('strike rate')
# Out:
# Text(0, 0.5, 'strike rate')

# %%
tips = sns.load_dataset('tips')

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips['total_bill'],tips['tip'],s=tips['size'])

# %%
plt.plot(tips['total_bill'],tips['tip'],'o',color='#3BE61A')

# %% [markdown]
# bar chart

# %%
mark =[50,88,66,44,82,39,35,99,75,58]
name =['a','b','c','d','e','f','j','h','i','k']

# %%
plt.bar(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# horizontal bar

# %%
plt.barh(mark,name,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
s = pd.read_csv('./datasets/bat_s.csv')

# %%
s
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(s['batsman'],s['2015'],color='yellow',width=0.1)
# Out:
# <BarContainer object of 5 artists>

# %%
s.shape
# Out:
# (5, 4)

# %%
np.arange(s.shape[0])
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# multiple bar plot

# %%
plt.bar(np.arange(s.shape[0])-0.2,s['2015'],width=0.2,color='#90E31C')
plt.bar(np.arange(s.shape[0]),s['2016'],width=0.2,color='#E7180B')
plt.bar(np.arange(s.shape[0])+0.2,s['2017'],width=0.2,color='#23AFA1')
plt.xticks(np.arange(s.shape[0]),s['batsman'])
plt.show()

# %%
plt.barh(np.arange(s.shape[0])-0.2,s['2015'],height=0.2,color='#23AFA1')
plt.barh(np.arange(s.shape[0]),s['2016'],height=0.2,color='#0C0A09')
plt.barh(np.arange(s.shape[0])+0.2,s['2017'],height=0.2,color='#7512ED')
plt.yticks(np.arange(s.shape[0]),s['batsman'])
plt.show()

# %% [markdown]
# Stacked bar chart

# %%
s
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(s['batsman'],s['2017'],label='2017',color='#C81609',width=0.5,edgecolor='black')
plt.bar(s['batsman'],s['2016'],bottom=s['2017'],label='2016',color='#0E0C0B',width=0.5,edgecolor='black')
plt.bar(s['batsman'],s['2015'],bottom=(s['2016']+s['2017']),label='2015',color="#E7E7E7",width=0.5,edgecolor='black')
plt.legend()
plt.show()

# %% [markdown]
# histrogram

# %%
plt.hist(mark,bins=[35,50,80,90],color='purple',edgecolor='white')
# Out:
# (array([3., 4., 2.]),
#  array([35., 50., 80., 90.]),
#  <BarContainer object of 3 artists>)

# %%
vk = pd.read_csv('./datasets/vk.csv')

# %%
vk.head(5)
# Out:
#    match_id  batsman_runs
# 0        12            62
# 1        17            28
# 2        20            64
# 3        27             0
# 4        30            10

# %%
plt.hist(vk['batsman_runs'],bins=[0,10,20,40,50,70,90,100,120,130],color='green',edgecolor='black',log=True)
plt.show()

# %% [markdown]
# creating a large npy array

# %%
import numpy as np

# Create a large array (e.g., 10 million random numbers)
large_array = np.random.rand(10_00_00)


np.save("large_array.npy", large_array)

# %%
arr =np.load('./datasets/large_array.npy',mmap_mode='r')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 arr =np.load('./datasets/large_array.npy',mmap_mode='r')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\numpy\lib\_npyio_impl.py:454, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     452     own_fid = False
#     453 else:
# --> 454     fid = stack.enter_context(open(os.fspath(file), "rb"))
#     455     own_fid = True
#     457 # Code to distinguish from NumPy binary files and pickles.
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/large_array.npy'

# %%
plt.hist(arr,color='blue',edgecolor='black',log=True)
plt.show()

# %% [markdown]
# pie chart

# %%
data =[29,55,85,66,46]
sub=['eng','sci','math','social','hindi']

plt.pie(data,labels=sub,autopct='%0.1f%%')
plt.show()

# %%
gayle = pd.read_csv('./datasets/gayle-175.csv')

# %%
gayle.shape
# Out:
# (6, 2)

# %%
gayle.head(5)
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33

# %%
plt.pie(gayle['batsman_runs'],labels=gayle['batsman'])
plt.show()

# %%
plt.pie(gayle['batsman_runs'],labels=gayle['batsman'],autopct='%0.1f%%')
plt.show()

# %%
plt.pie(gayle['batsman_runs'],labels=gayle['batsman'],autopct='%0.1f%%',explode=[0.2,0,0,0,0,0],shadow=True)
plt.savefig('piechart_gayle_run')

# %% [markdown]
# changing style in matplotlib

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']
